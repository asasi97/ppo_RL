# %%
import torch
import torch.nn as nn
from torch.distributions import MultivariateNormal
import gym
import numpy as np

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Memory:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []
    
    def clear_memory(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]

class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, action_std):
        super(ActorCritic, self).__init__()
        # action mean range -1 to 1
        self.actor =  nn.Sequential(
                nn.Linear(state_dim, 64),
                nn.Tanh(),
                nn.Linear(64, 32),
                nn.Tanh(),
                nn.Linear(32, action_dim),
                nn.Tanh()
                )
        # critic
        self.critic = nn.Sequential(
                nn.Linear(state_dim, 64),
                nn.Tanh(),
                nn.Linear(64, 32),
                nn.Tanh(),
                nn.Linear(32, 1)
                )
        self.action_var = torch.full((action_dim,), action_std*action_std).to(device)
        
    def forward(self):
        raise NotImplementedError
    
    def act(self, state, memory):
        action_mean = self.actor(state)
        cov_mat = torch.diag(self.action_var).to(device)
        
        dist = MultivariateNormal(action_mean, cov_mat)
        action = dist.sample()
        action_logprob = dist.log_prob(action)
        
        memory.states.append(state)
        memory.actions.append(action)
        memory.logprobs.append(action_logprob)
        
        return action.detach()
    
    def evaluate(self, state, action):   
        action_mean = self.actor(state)
        
        action_var = self.action_var.expand_as(action_mean)
        cov_mat = torch.diag_embed(action_var).to(device)
        
        dist = MultivariateNormal(action_mean, cov_mat)
        
        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        state_value = self.critic(state)
        
        return action_logprobs, torch.squeeze(state_value), dist_entropy

class PPO:
    def __init__(self, state_dim, action_dim, action_std, lr, betas, gamma, K_epochs, eps_clip):
        self.lr = lr
        self.betas = betas
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.policy = ActorCritic(state_dim, action_dim, action_std).to(device)
        self.optimizer = torch.optim.Adam(self.policy.parameters(), lr=lr, betas=betas)
        
        self.policy_old = ActorCritic(state_dim, action_dim, action_std).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        self.MseLoss = nn.MSELoss()
    
    def select_action(self, state, memory):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.policy_old.act(state, memory).cpu().data.numpy().flatten()
    
    def update(self, memory):
        # Monte Carlo estimate of rewards:
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(memory.rewards), reversed(memory.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
        
        # Normalizing the rewards:
        rewards = torch.tensor(rewards).to(device)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-5)
        
        # convert list to tensor
        old_states = torch.squeeze(torch.stack(memory.states).to(device), 1).detach()
        old_actions = torch.squeeze(torch.stack(memory.actions).to(device), 1).detach()
        old_logprobs = torch.squeeze(torch.stack(memory.logprobs), 1).to(device).detach()
        
        # Optimize policy for K epochs:
        for _ in range(self.K_epochs):
            # Evaluating old actions and values :
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)
            
            # Finding the ratio (pi_theta / pi_theta__old):
            ratios = torch.exp(logprobs - old_logprobs.detach())

            # Finding Surrogate Loss:
            advantages = rewards - state_values.detach()   
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
        # Copy new weights into old policy:
        self.policy_old.load_state_dict(self.policy.state_dict())
        
# def main():
############## Hyperparameters ##############
env_name = "BipedalWalker-v3"
render = False
solved_reward = 300         # stop training if avg_reward > solved_reward
log_interval = 20           # print avg reward in the interval
max_episodes = 10000        # max training episodes
max_timesteps = 1500        # max timesteps in one episode

update_timestep = 4000      # update policy every n timesteps
action_std = 0.5            # constant std for action distribution (Multivariate Normal)
K_epochs = 80               # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
gamma = 0.99                # discount factor

lr = 0.0003                 # parameters for Adam optimizer
betas = (0.9, 0.999)

random_seed = None
saved_model = False
#############################################

# creating environment
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

if random_seed:
    print("Random Seed: {}".format(random_seed))
    torch.manual_seed(random_seed)
    env.seed(random_seed)
    np.random.seed(random_seed)

memory = Memory()
ppo = PPO(state_dim, action_dim, action_std, lr, betas, gamma, K_epochs, eps_clip)
print(lr,betas)

# logging variables
running_reward = 0
avg_length = 0
time_step = 0

if saved_model:
#     PATH = 'PPO_continuous_BipedalWalker-v3-2000.pth'
    PATH = 'PPO_continuous_BipedalWalker-v2-fullytrained.pth'
    #         ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)
    ppo.policy.load_state_dict(torch.load(PATH))
    ppo.policy.eval()
    # ppo.policy.train()

# training loop
for i_episode in range(1, max_episodes+1):
    state = env.reset()
    for t in range(max_timesteps):
        time_step +=1
        # Running policy_old:
        action = ppo.select_action(state, memory)
        state, reward, done, _ = env.step(action)

        # Saving reward and is_terminals:
        memory.rewards.append(reward)
        memory.is_terminals.append(done)

        # update if its time
        if time_step % update_timestep == 0:
            ppo.update(memory)
            memory.clear_memory()
            time_step = 0
        running_reward += reward
        if render:
            env.render()
        if done:
            break

    avg_length += t

    # stop training if avg_reward > solved_reward
    if running_reward > (log_interval*solved_reward):
        print("########## Solved! ##########")
        torch.save(ppo.policy.state_dict(), './PPO_continuous_solved_{}.pth'.format(env_name))
        break

    # save every 500 episodes
    if i_episode % 500 == 0:
        torch.save(ppo.policy.state_dict(), './PPO_continuous_{}.pth'.format(env_name))

    # logging
    if i_episode % log_interval == 0:
        avg_length = int(avg_length/log_interval)
        running_reward = int((running_reward/log_interval))

        print('Episode {} \t Avg length: {} \t Avg reward: {}'.format(i_episode, avg_length, running_reward))
#             torch.save(ppo.policy.state_dict(), './PPO_{}.pth'.format(env_name))

        running_reward = 0
        avg_length = 0
            
# if __name__ == '__main__':
#     main()
# Out:
# /Users/adarshsasi97/miniconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 0.0003 (0.9, 0.999)
# Episode 20 	 Avg length: 146 	 Avg reward: -109
# Episode 40 	 Avg length: 79 	 Avg reward: -112
# Episode 60 	 Avg length: 74 	 Avg reward: -111
# Episode 80 	 Avg length: 154 	 Avg reward: -110
# Episode 100 	 Avg length: 152 	 Avg reward: -108
# Episode 120 	 Avg length: 144 	 Avg reward: -108
# Episode 140 	 Avg length: 568 	 Avg reward: -94
# Episode 160 	 Avg length: 425 	 Avg reward: -100
# Episode 180 	 Avg length: 714 	 Avg reward: -92
# Episode 200 	 Avg length: 1149 	 Avg reward: -76
# Episode 220 	 Avg length: 1294 	 Avg reward: -66
# Episode 240 	 Avg length: 1431 	 Avg reward: -59
# Episode 260 	 Avg length: 1355 	 Avg reward: -60
# Episode 280 	 Avg length: 1355 	 Avg reward: -58
# Episode 300 	 Avg length: 1427 	 Avg reward: -55
# Episode 320 	 Avg length: 1151 	 Avg reward: -63
# Episode 340 	 Avg length: 1285 	 Avg reward: -54
# Episode 360 	 Avg length: 722 	 Avg reward: -77
# Episode 380 	 Avg length: 580 	 Avg reward: -83
# Episode 400 	 Avg length: 1143 	 Avg reward: -54
# Episode 420 	 Avg length: 1360 	 Avg reward: -35
# Episode 440 	 Avg length: 1287 	 Avg reward: -23
# Episode 460 	 Avg length: 1209 	 Avg reward: -20
# Episode 480 	 Avg length: 1354 	 Avg reward: 11
# Episode 500 	 Avg length: 1308 	 Avg reward: 25
# Episode 520 	 Avg length: 1118 	 Avg reward: 11
# Episode 540 	 Avg length: 1064 	 Avg reward: 6
# Episode 560 	 Avg length: 976 	 Avg reward: -2
# Episode 580 	 Avg length: 1110 	 Avg reward: 27
# Episode 600 	 Avg length: 1187 	 Avg reward: 30
# Episode 620 	 Avg length: 1220 	 Avg reward: 37
# Episode 640 	 Avg length: 1340 	 Avg reward: 87
# Episode 660 	 Avg length: 1269 	 Avg reward: 82
# Episode 680 	 Avg length: 1251 	 Avg reward: 73
# Episode 700 	 Avg length: 1321 	 Avg reward: 109
# Episode 720 	 Avg length: 1165 	 Avg reward: 78
# Episode 740 	 Avg length: 1372 	 Avg reward: 105
# Episode 760 	 Avg length: 1086 	 Avg reward: 61
# Episode 780 	 Avg length: 1126 	 Avg reward: 78
# Episode 800 	 Avg length: 1405 	 Avg reward: 130
# Episode 820 	 Avg length: 1284 	 Avg reward: 105
# Episode 840 	 Avg length: 1195 	 Avg reward: 92
# Episode 860 	 Avg length: 1014 	 Avg reward: 52
# Episode 880 	 Avg length: 1365 	 Avg reward: 152
# Episode 900 	 Avg length: 1094 	 Avg reward: 82
# Episode 920 	 Avg length: 1283 	 Avg reward: 125
# Episode 940 	 Avg length: 1214 	 Avg reward: 88
# Episode 960 	 Avg length: 1331 	 Avg reward: 143
# Episode 980 	 Avg length: 1148 	 Avg reward: 98
# Episode 1000 	 Avg length: 1304 	 Avg reward: 133
# Episode 1020 	 Avg length: 1190 	 Avg reward: 114
# Episode 1040 	 Avg length: 1260 	 Avg reward: 132
# Episode 1060 	 Avg length: 1298 	 Avg reward: 134
# Episode 1080 	 Avg length: 1165 	 Avg reward: 103
# Episode 1100 	 Avg length: 1332 	 Avg reward: 143
# Episode 1120 	 Avg length: 1419 	 Avg reward: 168
# Episode 1140 	 Avg length: 1359 	 Avg reward: 164
# Episode 1160 	 Avg length: 1315 	 Avg reward: 152
# Episode 1180 	 Avg length: 1410 	 Avg reward: 168
# Episode 1200 	 Avg length: 1267 	 Avg reward: 134
# Episode 1220 	 Avg length: 1168 	 Avg reward: 124
# Episode 1240 	 Avg length: 1222 	 Avg reward: 123
# Episode 1260 	 Avg length: 1109 	 Avg reward: 116
# Episode 1280 	 Avg length: 1298 	 Avg reward: 150
# Episode 1300 	 Avg length: 1050 	 Avg reward: 88
# Episode 1320 	 Avg length: 977 	 Avg reward: 74
# Episode 1340 	 Avg length: 982 	 Avg reward: 72
# Episode 1360 	 Avg length: 1125 	 Avg reward: 103
# Episode 1380 	 Avg length: 1285 	 Avg reward: 150
# Episode 1400 	 Avg length: 1403 	 Avg reward: 184
# Episode 1420 	 Avg length: 1314 	 Avg reward: 159
# Episode 1440 	 Avg length: 1351 	 Avg reward: 164
# Episode 1460 	 Avg length: 1341 	 Avg reward: 153
# Episode 1480 	 Avg length: 1304 	 Avg reward: 159
# Episode 1500 	 Avg length: 1416 	 Avg reward: 183
# Episode 1520 	 Avg length: 1407 	 Avg reward: 186
# Episode 1540 	 Avg length: 1294 	 Avg reward: 158
# Episode 1560 	 Avg length: 1195 	 Avg reward: 134
# Episode 1580 	 Avg length: 1331 	 Avg reward: 164
# Episode 1600 	 Avg length: 1411 	 Avg reward: 189
# Episode 1620 	 Avg length: 1015 	 Avg reward: 92
# Episode 1640 	 Avg length: 1317 	 Avg reward: 177
# Episode 1660 	 Avg length: 1107 	 Avg reward: 119
# Episode 1680 	 Avg length: 1197 	 Avg reward: 146
# Episode 1700 	 Avg length: 1093 	 Avg reward: 121
# Episode 1720 	 Avg length: 1139 	 Avg reward: 121
# Episode 1740 	 Avg length: 1259 	 Avg reward: 159
# Episode 1760 	 Avg length: 1282 	 Avg reward: 160
# Episode 1780 	 Avg length: 1172 	 Avg reward: 122
# Episode 1800 	 Avg length: 962 	 Avg reward: 78
# Episode 1820 	 Avg length: 1246 	 Avg reward: 135
# Episode 1840 	 Avg length: 1240 	 Avg reward: 140
# Episode 1860 	 Avg length: 1396 	 Avg reward: 182
# Episode 1880 	 Avg length: 1365 	 Avg reward: 178
# Episode 1900 	 Avg length: 1196 	 Avg reward: 134
# Episode 1920 	 Avg length: 1134 	 Avg reward: 117
# Episode 1940 	 Avg length: 1281 	 Avg reward: 159
# Episode 1960 	 Avg length: 1390 	 Avg reward: 187
# Episode 1980 	 Avg length: 1487 	 Avg reward: 211
# Episode 2000 	 Avg length: 1322 	 Avg reward: 170
# Episode 2020 	 Avg length: 1297 	 Avg reward: 158
# Episode 2040 	 Avg length: 1363 	 Avg reward: 177
# Episode 2060 	 Avg length: 1409 	 Avg reward: 191
# Episode 2080 	 Avg length: 1339 	 Avg reward: 177
# Episode 2100 	 Avg length: 1220 	 Avg reward: 129
# Episode 2120 	 Avg length: 1040 	 Avg reward: 102
# Episode 2140 	 Avg length: 1259 	 Avg reward: 151
# Episode 2160 	 Avg length: 1312 	 Avg reward: 163
# Episode 2180 	 Avg length: 1269 	 Avg reward: 146
# Episode 2200 	 Avg length: 1468 	 Avg reward: 204
# Episode 2220 	 Avg length: 1296 	 Avg reward: 156
# Episode 2240 	 Avg length: 1389 	 Avg reward: 186
# Episode 2260 	 Avg length: 1335 	 Avg reward: 157
# Episode 2280 	 Avg length: 1444 	 Avg reward: 201
# Episode 2300 	 Avg length: 1315 	 Avg reward: 159
# Episode 2320 	 Avg length: 1357 	 Avg reward: 181
# Episode 2340 	 Avg length: 1183 	 Avg reward: 126
# Episode 2360 	 Avg length: 1388 	 Avg reward: 186
# Episode 2380 	 Avg length: 1251 	 Avg reward: 152
# Episode 2400 	 Avg length: 1057 	 Avg reward: 93
# Episode 2420 	 Avg length: 1386 	 Avg reward: 181
# Episode 2440 	 Avg length: 1111 	 Avg reward: 119
# Episode 2460 	 Avg length: 1155 	 Avg reward: 124
# Episode 2480 	 Avg length: 1237 	 Avg reward: 150
# Episode 2500 	 Avg length: 1290 	 Avg reward: 161
# Episode 2520 	 Avg length: 1265 	 Avg reward: 155
# Episode 2540 	 Avg length: 1290 	 Avg reward: 156
# Episode 2560 	 Avg length: 1086 	 Avg reward: 110
# Episode 2580 	 Avg length: 1368 	 Avg reward: 170
# Episode 2600 	 Avg length: 1280 	 Avg reward: 151
# Episode 2620 	 Avg length: 1164 	 Avg reward: 121
# Episode 2640 	 Avg length: 1088 	 Avg reward: 95
# Episode 2660 	 Avg length: 1255 	 Avg reward: 161
# Episode 2680 	 Avg length: 1227 	 Avg reward: 146
# Episode 2700 	 Avg length: 1302 	 Avg reward: 153
# Episode 2720 	 Avg length: 1243 	 Avg reward: 149
# Episode 2740 	 Avg length: 1272 	 Avg reward: 143
# Episode 2760 	 Avg length: 1232 	 Avg reward: 145
# Episode 2780 	 Avg length: 1110 	 Avg reward: 114
# Episode 2800 	 Avg length: 1296 	 Avg reward: 156
# Episode 2820 	 Avg length: 1090 	 Avg reward: 106
# Episode 2840 	 Avg length: 1257 	 Avg reward: 134
# Episode 2860 	 Avg length: 1022 	 Avg reward: 78
# Episode 2880 	 Avg length: 1327 	 Avg reward: 160
# Episode 2900 	 Avg length: 1275 	 Avg reward: 131
# Episode 2920 	 Avg length: 1293 	 Avg reward: 157
# Episode 2940 	 Avg length: 1159 	 Avg reward: 117
# Episode 2960 	 Avg length: 1302 	 Avg reward: 147
# Episode 2980 	 Avg length: 1428 	 Avg reward: 185
# Episode 3000 	 Avg length: 1291 	 Avg reward: 145
# Episode 3020 	 Avg length: 1209 	 Avg reward: 120
# Episode 3040 	 Avg length: 1311 	 Avg reward: 153
# Episode 3060 	 Avg length: 1238 	 Avg reward: 127
# Episode 3080 	 Avg length: 1437 	 Avg reward: 193
# Episode 3100 	 Avg length: 1386 	 Avg reward: 182
# Episode 3120 	 Avg length: 1369 	 Avg reward: 180
# Episode 3140 	 Avg length: 1305 	 Avg reward: 160
# Episode 3160 	 Avg length: 1372 	 Avg reward: 178
# Episode 3180 	 Avg length: 1318 	 Avg reward: 159
# Episode 3200 	 Avg length: 1340 	 Avg reward: 168
# Episode 3220 	 Avg length: 1214 	 Avg reward: 115
# Episode 3240 	 Avg length: 1165 	 Avg reward: 116
# Episode 3260 	 Avg length: 1353 	 Avg reward: 169
# Episode 3280 	 Avg length: 1262 	 Avg reward: 132
# Episode 3300 	 Avg length: 1337 	 Avg reward: 160
# Episode 3320 	 Avg length: 1258 	 Avg reward: 133
# Episode 3340 	 Avg length: 1388 	 Avg reward: 160
# Episode 3360 	 Avg length: 1191 	 Avg reward: 116
# Episode 3380 	 Avg length: 1258 	 Avg reward: 122
# Episode 3400 	 Avg length: 1234 	 Avg reward: 124
# Episode 3420 	 Avg length: 1372 	 Avg reward: 157
# Episode 3440 	 Avg length: 1104 	 Avg reward: 94
# Episode 3460 	 Avg length: 1260 	 Avg reward: 138
# Episode 3480 	 Avg length: 1210 	 Avg reward: 124
# Episode 3500 	 Avg length: 1228 	 Avg reward: 120
# Episode 3520 	 Avg length: 1345 	 Avg reward: 162
# Episode 3540 	 Avg length: 1373 	 Avg reward: 157
# Episode 3560 	 Avg length: 1312 	 Avg reward: 160
# Episode 3580 	 Avg length: 1353 	 Avg reward: 160
# Episode 3600 	 Avg length: 1322 	 Avg reward: 153
# Episode 3620 	 Avg length: 1243 	 Avg reward: 142
# Episode 3640 	 Avg length: 1282 	 Avg reward: 153
# Episode 3660 	 Avg length: 1285 	 Avg reward: 137
# Episode 3680 	 Avg length: 1121 	 Avg reward: 111
# Episode 3700 	 Avg length: 1360 	 Avg reward: 158
# Episode 3720 	 Avg length: 1397 	 Avg reward: 183
# Episode 3740 	 Avg length: 1245 	 Avg reward: 144
# Episode 3760 	 Avg length: 1397 	 Avg reward: 181
# Episode 3780 	 Avg length: 1179 	 Avg reward: 124
# Episode 3800 	 Avg length: 1491 	 Avg reward: 210
# Episode 3820 	 Avg length: 1413 	 Avg reward: 189
# Episode 3840 	 Avg length: 1256 	 Avg reward: 145
# Episode 3860 	 Avg length: 1257 	 Avg reward: 145
# Episode 3880 	 Avg length: 1421 	 Avg reward: 191
# Episode 3900 	 Avg length: 1303 	 Avg reward: 160
# Episode 3920 	 Avg length: 1381 	 Avg reward: 188
# Episode 3940 	 Avg length: 1356 	 Avg reward: 172
# Episode 3960 	 Avg length: 1164 	 Avg reward: 118
# Episode 3980 	 Avg length: 1425 	 Avg reward: 188
# Episode 4000 	 Avg length: 1359 	 Avg reward: 182
# Episode 4020 	 Avg length: 1348 	 Avg reward: 169
# Episode 4040 	 Avg length: 1324 	 Avg reward: 169
# Episode 4060 	 Avg length: 1262 	 Avg reward: 149
# Episode 4080 	 Avg length: 1195 	 Avg reward: 133
# Episode 4100 	 Avg length: 1317 	 Avg reward: 166
# Episode 4120 	 Avg length: 1327 	 Avg reward: 171
# Episode 4140 	 Avg length: 1118 	 Avg reward: 103
# Episode 4160 	 Avg length: 1252 	 Avg reward: 156
# Episode 4180 	 Avg length: 1253 	 Avg reward: 148
# Episode 4200 	 Avg length: 1205 	 Avg reward: 141
# Episode 4220 	 Avg length: 1123 	 Avg reward: 123
# Episode 4240 	 Avg length: 1184 	 Avg reward: 116
# Episode 4260 	 Avg length: 1284 	 Avg reward: 158
# Episode 4280 	 Avg length: 1464 	 Avg reward: 211
# Episode 4300 	 Avg length: 1331 	 Avg reward: 161
# Episode 4320 	 Avg length: 1265 	 Avg reward: 147
# Episode 4340 	 Avg length: 1318 	 Avg reward: 152
# Episode 4360 	 Avg length: 1396 	 Avg reward: 183
# Episode 4380 	 Avg length: 1278 	 Avg reward: 150
# Episode 4400 	 Avg length: 1463 	 Avg reward: 198
# Episode 4420 	 Avg length: 1417 	 Avg reward: 189
# Episode 4440 	 Avg length: 1371 	 Avg reward: 172
# Episode 4460 	 Avg length: 1206 	 Avg reward: 127
# Episode 4480 	 Avg length: 1172 	 Avg reward: 127
# Episode 4500 	 Avg length: 1372 	 Avg reward: 174
# Episode 4520 	 Avg length: 1391 	 Avg reward: 169
# Episode 4540 	 Avg length: 1370 	 Avg reward: 180
# Episode 4560 	 Avg length: 1284 	 Avg reward: 142
# Episode 4580 	 Avg length: 1231 	 Avg reward: 130
# Episode 4600 	 Avg length: 1270 	 Avg reward: 161
# Episode 4620 	 Avg length: 1339 	 Avg reward: 174
# Episode 4640 	 Avg length: 1332 	 Avg reward: 156
# Episode 4660 	 Avg length: 1081 	 Avg reward: 84
# Episode 4680 	 Avg length: 1330 	 Avg reward: 168
# Episode 4700 	 Avg length: 1386 	 Avg reward: 191
# Episode 4720 	 Avg length: 1402 	 Avg reward: 179
# Episode 4740 	 Avg length: 1278 	 Avg reward: 152
# Episode 4760 	 Avg length: 1386 	 Avg reward: 173
# Episode 4780 	 Avg length: 1258 	 Avg reward: 153
# Episode 4800 	 Avg length: 1208 	 Avg reward: 136
# Episode 4820 	 Avg length: 1389 	 Avg reward: 183
# Episode 4840 	 Avg length: 1400 	 Avg reward: 172
# Episode 4860 	 Avg length: 1293 	 Avg reward: 165
# Episode 4880 	 Avg length: 1468 	 Avg reward: 203
# Episode 4900 	 Avg length: 1410 	 Avg reward: 187
# Episode 4920 	 Avg length: 1364 	 Avg reward: 188
# Episode 4940 	 Avg length: 1044 	 Avg reward: 91
# Episode 4960 	 Avg length: 1144 	 Avg reward: 116
# Episode 4980 	 Avg length: 1387 	 Avg reward: 186
# Episode 5000 	 Avg length: 1221 	 Avg reward: 146
# Episode 5020 	 Avg length: 1222 	 Avg reward: 139
# Episode 5040 	 Avg length: 1327 	 Avg reward: 176
# Episode 5060 	 Avg length: 1015 	 Avg reward: 80
# Episode 5080 	 Avg length: 1144 	 Avg reward: 124
# Episode 5100 	 Avg length: 1267 	 Avg reward: 149
# Episode 5120 	 Avg length: 1166 	 Avg reward: 126
# Episode 5140 	 Avg length: 1280 	 Avg reward: 143
# Episode 5160 	 Avg length: 1397 	 Avg reward: 186
# Episode 5180 	 Avg length: 1401 	 Avg reward: 195
# Episode 5200 	 Avg length: 1344 	 Avg reward: 164
# Episode 5220 	 Avg length: 1406 	 Avg reward: 195
# Episode 5240 	 Avg length: 1451 	 Avg reward: 210
# Episode 5260 	 Avg length: 1420 	 Avg reward: 203
# Episode 5280 	 Avg length: 1361 	 Avg reward: 189
# Episode 5300 	 Avg length: 1206 	 Avg reward: 146
# Episode 5320 	 Avg length: 1334 	 Avg reward: 186
# Episode 5340 	 Avg length: 1375 	 Avg reward: 193
# Episode 5360 	 Avg length: 1372 	 Avg reward: 190
# Episode 5380 	 Avg length: 1254 	 Avg reward: 168
# Episode 5400 	 Avg length: 1336 	 Avg reward: 175
# Episode 5420 	 Avg length: 1410 	 Avg reward: 197
# Episode 5440 	 Avg length: 1413 	 Avg reward: 209
# Episode 5460 	 Avg length: 1405 	 Avg reward: 194
# Episode 5480 	 Avg length: 1404 	 Avg reward: 200
# Episode 5500 	 Avg length: 1315 	 Avg reward: 170
# Episode 5520 	 Avg length: 1213 	 Avg reward: 161
# Episode 5540 	 Avg length: 1322 	 Avg reward: 189
# Episode 5560 	 Avg length: 1286 	 Avg reward: 175
# Episode 5580 	 Avg length: 1344 	 Avg reward: 191
# Episode 5600 	 Avg length: 1395 	 Avg reward: 201
# Episode 5620 	 Avg length: 1285 	 Avg reward: 177
# Episode 5640 	 Avg length: 1250 	 Avg reward: 162
# Episode 5660 	 Avg length: 1404 	 Avg reward: 202
# Episode 5680 	 Avg length: 1273 	 Avg reward: 158
# Episode 5700 	 Avg length: 1286 	 Avg reward: 149
# Episode 5720 	 Avg length: 1459 	 Avg reward: 217
# Episode 5740 	 Avg length: 1345 	 Avg reward: 185
# Episode 5760 	 Avg length: 1447 	 Avg reward: 208
# Episode 5780 	 Avg length: 1353 	 Avg reward: 202
# Episode 5800 	 Avg length: 1345 	 Avg reward: 200
# Episode 5820 	 Avg length: 1251 	 Avg reward: 166
# Episode 5840 	 Avg length: 1343 	 Avg reward: 183
# Episode 5860 	 Avg length: 1344 	 Avg reward: 191
# Episode 5880 	 Avg length: 1405 	 Avg reward: 202
# Episode 5900 	 Avg length: 1293 	 Avg reward: 183
# Episode 5920 	 Avg length: 1406 	 Avg reward: 209
# Episode 5940 	 Avg length: 1425 	 Avg reward: 221
# Episode 5960 	 Avg length: 1337 	 Avg reward: 198
# Episode 5980 	 Avg length: 1327 	 Avg reward: 192
# Episode 6000 	 Avg length: 1478 	 Avg reward: 239
# Episode 6020 	 Avg length: 1351 	 Avg reward: 194
# Episode 6040 	 Avg length: 1422 	 Avg reward: 214
# Episode 6060 	 Avg length: 1452 	 Avg reward: 213
# Episode 6080 	 Avg length: 1374 	 Avg reward: 197
# Episode 6100 	 Avg length: 1388 	 Avg reward: 202
# Episode 6120 	 Avg length: 1408 	 Avg reward: 212
# Episode 6140 	 Avg length: 1443 	 Avg reward: 201
# Episode 6160 	 Avg length: 1310 	 Avg reward: 185
# Episode 6180 	 Avg length: 1429 	 Avg reward: 199
# Episode 6200 	 Avg length: 1273 	 Avg reward: 167
# Episode 6220 	 Avg length: 1258 	 Avg reward: 158
# Episode 6240 	 Avg length: 1364 	 Avg reward: 193
# Episode 6260 	 Avg length: 1253 	 Avg reward: 176
# Episode 6280 	 Avg length: 1393 	 Avg reward: 208
# Episode 6300 	 Avg length: 1408 	 Avg reward: 209
# Episode 6320 	 Avg length: 1347 	 Avg reward: 187
# Episode 6340 	 Avg length: 1355 	 Avg reward: 189
# Episode 6360 	 Avg length: 1236 	 Avg reward: 152
# Episode 6380 	 Avg length: 1373 	 Avg reward: 195
# Episode 6400 	 Avg length: 1194 	 Avg reward: 137
# Episode 6420 	 Avg length: 1191 	 Avg reward: 145
# Episode 6440 	 Avg length: 1247 	 Avg reward: 153
# Episode 6460 	 Avg length: 1386 	 Avg reward: 198
# Episode 6480 	 Avg length: 1209 	 Avg reward: 148
# Episode 6500 	 Avg length: 1340 	 Avg reward: 199
# Episode 6520 	 Avg length: 1376 	 Avg reward: 197
# Episode 6540 	 Avg length: 1417 	 Avg reward: 205
# Episode 6560 	 Avg length: 1188 	 Avg reward: 121
# Episode 6580 	 Avg length: 1165 	 Avg reward: 144
# Episode 6600 	 Avg length: 1433 	 Avg reward: 216
# Episode 6620 	 Avg length: 1310 	 Avg reward: 178
# Episode 6640 	 Avg length: 1260 	 Avg reward: 170
# Episode 6660 	 Avg length: 1166 	 Avg reward: 145
# Episode 6680 	 Avg length: 1146 	 Avg reward: 150
# Episode 6700 	 Avg length: 1138 	 Avg reward: 147
# Episode 6720 	 Avg length: 1347 	 Avg reward: 206
# Episode 6740 	 Avg length: 1262 	 Avg reward: 173
# Episode 6760 	 Avg length: 1385 	 Avg reward: 196
# Episode 6780 	 Avg length: 1350 	 Avg reward: 192
# Episode 6800 	 Avg length: 1144 	 Avg reward: 140
# Episode 6820 	 Avg length: 1189 	 Avg reward: 155
# Episode 6840 	 Avg length: 1181 	 Avg reward: 163
# Episode 6860 	 Avg length: 1230 	 Avg reward: 165
# Episode 6880 	 Avg length: 1269 	 Avg reward: 174
# Episode 6900 	 Avg length: 1251 	 Avg reward: 170
# Episode 6920 	 Avg length: 1205 	 Avg reward: 163
# Episode 6940 	 Avg length: 1175 	 Avg reward: 152
# Episode 6960 	 Avg length: 1316 	 Avg reward: 185
# Episode 6980 	 Avg length: 1348 	 Avg reward: 197
# Episode 7000 	 Avg length: 1404 	 Avg reward: 213
# Episode 7020 	 Avg length: 1276 	 Avg reward: 179
# Episode 7040 	 Avg length: 1296 	 Avg reward: 185
# Episode 7060 	 Avg length: 1235 	 Avg reward: 180
# Episode 7080 	 Avg length: 1069 	 Avg reward: 121
# Episode 7100 	 Avg length: 1221 	 Avg reward: 171
# Episode 7120 	 Avg length: 1143 	 Avg reward: 156
# Episode 7140 	 Avg length: 1265 	 Avg reward: 185
# Episode 7160 	 Avg length: 1288 	 Avg reward: 191
# Episode 7180 	 Avg length: 1272 	 Avg reward: 181
# Episode 7200 	 Avg length: 1305 	 Avg reward: 194
# Episode 7220 	 Avg length: 1217 	 Avg reward: 178
# Episode 7240 	 Avg length: 1132 	 Avg reward: 123
# Episode 7260 	 Avg length: 1304 	 Avg reward: 196
# Episode 7280 	 Avg length: 1234 	 Avg reward: 184
# Episode 7300 	 Avg length: 1231 	 Avg reward: 162
# Episode 7320 	 Avg length: 1386 	 Avg reward: 210
# Episode 7340 	 Avg length: 1130 	 Avg reward: 130
# Episode 7360 	 Avg length: 1243 	 Avg reward: 168
# Episode 7380 	 Avg length: 962 	 Avg reward: 100
# Episode 7400 	 Avg length: 1163 	 Avg reward: 168
# Episode 7420 	 Avg length: 1179 	 Avg reward: 154
# Episode 7440 	 Avg length: 1220 	 Avg reward: 176
# Episode 7460 	 Avg length: 1225 	 Avg reward: 179
# Episode 7480 	 Avg length: 1289 	 Avg reward: 175
# Episode 7500 	 Avg length: 1345 	 Avg reward: 206
# Episode 7520 	 Avg length: 1161 	 Avg reward: 147
# Episode 7540 	 Avg length: 1199 	 Avg reward: 173
# Episode 7560 	 Avg length: 1358 	 Avg reward: 219
# Episode 7580 	 Avg length: 1401 	 Avg reward: 226
# Episode 7600 	 Avg length: 1338 	 Avg reward: 197
# Episode 7620 	 Avg length: 1341 	 Avg reward: 206
# Episode 7640 	 Avg length: 1066 	 Avg reward: 132
# Episode 7660 	 Avg length: 1313 	 Avg reward: 208
# Episode 7680 	 Avg length: 1147 	 Avg reward: 158
# Episode 7700 	 Avg length: 1095 	 Avg reward: 170
# Episode 7720 	 Avg length: 690 	 Avg reward: 40
# Episode 7740 	 Avg length: 1123 	 Avg reward: 175
# Episode 7760 	 Avg length: 912 	 Avg reward: 99
# Episode 7780 	 Avg length: 725 	 Avg reward: 33
# Episode 7800 	 Avg length: 1066 	 Avg reward: 128
# Episode 7820 	 Avg length: 1160 	 Avg reward: 157
# Episode 7840 	 Avg length: 1200 	 Avg reward: 161
# Episode 7860 	 Avg length: 1074 	 Avg reward: 112
# Episode 7880 	 Avg length: 1279 	 Avg reward: 176
# Episode 7900 	 Avg length: 1069 	 Avg reward: 132
# Episode 7920 	 Avg length: 1032 	 Avg reward: 128
# Episode 7940 	 Avg length: 1250 	 Avg reward: 170
# Episode 7960 	 Avg length: 1156 	 Avg reward: 143
# Episode 7980 	 Avg length: 1246 	 Avg reward: 167
# Episode 8000 	 Avg length: 1163 	 Avg reward: 148
# Episode 8020 	 Avg length: 1241 	 Avg reward: 163
# Episode 8040 	 Avg length: 1165 	 Avg reward: 129
# Episode 8060 	 Avg length: 1059 	 Avg reward: 119
# Episode 8080 	 Avg length: 1163 	 Avg reward: 129
# Episode 8100 	 Avg length: 1178 	 Avg reward: 152
# Episode 8120 	 Avg length: 1154 	 Avg reward: 143
# Episode 8140 	 Avg length: 868 	 Avg reward: 75
# Episode 8160 	 Avg length: 909 	 Avg reward: 98
# Episode 8180 	 Avg length: 916 	 Avg reward: 77
# Episode 8200 	 Avg length: 1180 	 Avg reward: 151
# Episode 8220 	 Avg length: 1079 	 Avg reward: 124
# Episode 8240 	 Avg length: 1295 	 Avg reward: 174
# Episode 8260 	 Avg length: 960 	 Avg reward: 103
# Episode 8280 	 Avg length: 1186 	 Avg reward: 152
# Episode 8300 	 Avg length: 1137 	 Avg reward: 145
# Episode 8320 	 Avg length: 988 	 Avg reward: 113
# Episode 8340 	 Avg length: 1092 	 Avg reward: 135
# Episode 8360 	 Avg length: 1216 	 Avg reward: 153
# Episode 8380 	 Avg length: 1222 	 Avg reward: 171
# Episode 8400 	 Avg length: 1130 	 Avg reward: 121
# Episode 8420 	 Avg length: 996 	 Avg reward: 103
# Episode 8440 	 Avg length: 1247 	 Avg reward: 173
# Episode 8460 	 Avg length: 1038 	 Avg reward: 128
# Episode 8480 	 Avg length: 1020 	 Avg reward: 108
# Episode 8500 	 Avg length: 1053 	 Avg reward: 134
# Episode 8520 	 Avg length: 1096 	 Avg reward: 142
# Episode 8540 	 Avg length: 950 	 Avg reward: 92
# Episode 8560 	 Avg length: 1148 	 Avg reward: 158
# Episode 8580 	 Avg length: 914 	 Avg reward: 86
# Episode 8600 	 Avg length: 1037 	 Avg reward: 122
# Episode 8620 	 Avg length: 990 	 Avg reward: 121
# Episode 8640 	 Avg length: 889 	 Avg reward: 69
# Episode 8660 	 Avg length: 875 	 Avg reward: 68
# Episode 8680 	 Avg length: 908 	 Avg reward: 75
# Episode 8700 	 Avg length: 964 	 Avg reward: 105
# Episode 8720 	 Avg length: 1141 	 Avg reward: 162
# Episode 8740 	 Avg length: 903 	 Avg reward: 94
# Episode 8760 	 Avg length: 808 	 Avg reward: 80
# Episode 8780 	 Avg length: 972 	 Avg reward: 111
# Episode 8800 	 Avg length: 845 	 Avg reward: 71
# Episode 8820 	 Avg length: 898 	 Avg reward: 106
# Episode 8840 	 Avg length: 895 	 Avg reward: 107
# Episode 8860 	 Avg length: 924 	 Avg reward: 107
# Episode 8880 	 Avg length: 961 	 Avg reward: 101
# Episode 8900 	 Avg length: 762 	 Avg reward: 51
# Episode 8920 	 Avg length: 954 	 Avg reward: 111
# Episode 8940 	 Avg length: 1122 	 Avg reward: 173
# Episode 8960 	 Avg length: 910 	 Avg reward: 103
# Episode 8980 	 Avg length: 860 	 Avg reward: 86
# Episode 9000 	 Avg length: 1040 	 Avg reward: 138
# Episode 9020 	 Avg length: 1022 	 Avg reward: 130
# Episode 9040 	 Avg length: 1133 	 Avg reward: 157
# Episode 9060 	 Avg length: 1153 	 Avg reward: 160
# Episode 9080 	 Avg length: 1058 	 Avg reward: 136
# Episode 9100 	 Avg length: 935 	 Avg reward: 108
# Episode 9120 	 Avg length: 1297 	 Avg reward: 193
# Episode 9140 	 Avg length: 1101 	 Avg reward: 161
# Episode 9160 	 Avg length: 1015 	 Avg reward: 116
# Episode 9180 	 Avg length: 953 	 Avg reward: 100
# Episode 9200 	 Avg length: 1095 	 Avg reward: 160
# Episode 9220 	 Avg length: 981 	 Avg reward: 114
# Episode 9240 	 Avg length: 979 	 Avg reward: 116
# Episode 9260 	 Avg length: 913 	 Avg reward: 100
# Episode 9280 	 Avg length: 1086 	 Avg reward: 146
# Episode 9300 	 Avg length: 850 	 Avg reward: 68
# Episode 9320 	 Avg length: 1055 	 Avg reward: 136
# Episode 9340 	 Avg length: 896 	 Avg reward: 97
# Episode 9360 	 Avg length: 971 	 Avg reward: 120
# Episode 9380 	 Avg length: 1162 	 Avg reward: 176
# Episode 9400 	 Avg length: 1064 	 Avg reward: 148
# Episode 9420 	 Avg length: 1085 	 Avg reward: 141
# Episode 9440 	 Avg length: 1086 	 Avg reward: 148
# Episode 9460 	 Avg length: 1056 	 Avg reward: 148
# Episode 9480 	 Avg length: 1049 	 Avg reward: 145
# Episode 9500 	 Avg length: 1155 	 Avg reward: 170
# Episode 9520 	 Avg length: 1005 	 Avg reward: 149
# Episode 9540 	 Avg length: 772 	 Avg reward: 67
# Episode 9560 	 Avg length: 885 	 Avg reward: 93
# Episode 9580 	 Avg length: 760 	 Avg reward: 77
# Episode 9600 	 Avg length: 1043 	 Avg reward: 152
# Episode 9620 	 Avg length: 1136 	 Avg reward: 170
# Episode 9640 	 Avg length: 1005 	 Avg reward: 142
# Episode 9660 	 Avg length: 835 	 Avg reward: 86
# Episode 9680 	 Avg length: 1163 	 Avg reward: 173
# Episode 9700 	 Avg length: 1034 	 Avg reward: 141
# Episode 9720 	 Avg length: 1094 	 Avg reward: 174
# Episode 9740 	 Avg length: 977 	 Avg reward: 119
# Episode 9760 	 Avg length: 1109 	 Avg reward: 154
# Episode 9780 	 Avg length: 1020 	 Avg reward: 127
# Episode 9800 	 Avg length: 1149 	 Avg reward: 190
# Episode 9820 	 Avg length: 1189 	 Avg reward: 183
# Episode 9840 	 Avg length: 870 	 Avg reward: 93
# Episode 9860 	 Avg length: 878 	 Avg reward: 105
# Episode 9880 	 Avg length: 1028 	 Avg reward: 153
# Episode 9900 	 Avg length: 854 	 Avg reward: 97
# Episode 9920 	 Avg length: 921 	 Avg reward: 94
# Episode 9940 	 Avg length: 895 	 Avg reward: 110
# Episode 9960 	 Avg length: 1050 	 Avg reward: 155
# Episode 9980 	 Avg length: 1032 	 Avg reward: 150
# Episode 10000 	 Avg length: 1062 	 Avg reward: 156

# %%
# Load and run the policy for visualization? - Thats the replacement for .eval
# Try .eval and .load with Cassie if possible?
#  Save the model using Zhaoming's code. Save the model exactly and let's see what happens?
import numpy as np

env = gym.make(env_name)
state = env.reset()
running_reward = 0
done = False
PATH = 'PPO_continuous_BipedalWalker-v3-2000.pth'
# PATH = 'PPO_continuous_BipedalWalker-v2-fullytrained.pth'
ppo.policy.load_state_dict(torch.load(PATH))
state_action_list = []

while not done:
    action = ppo.select_action(state, memory)
    env.render()
    state,reward,done,_ = env.step(action)
    running_reward += reward
    state_action_list.append([state,action])

print(running_reward)
np.save('state_action_bipedal.npy',state_action_list)
env.close()
# Out:
# 254.06209483377606
